.512039,147238700\n2006-11-15,12.150000,12.271428,12.000000,12.007143,10.394552,163830800\n2006-11-16,12.124286,12.328571,12.088572,12.230000,10.587480,173485200\n2006-11-17,12.162857,12.277143,12.142858,12.264286,10.617161,116606000\n2006-11-20,12.200000,12.428572,12.171429,12.352858,10.693839,142698500\n2006-11-21,12.488571,12.657143,12.444285,12.657143,10.957254,155666700\n2006-11-22,12.712857,12.964286,12.550000,12.901428,11.168736,167985300\n2006-11-24,12.790000,13.297143,12.785714,13.090000,11.331979,129669400\n2006-11-27,13.215714,13.308572,12.785714,12.791429,11.073504,268709000\n2006-11-28,12.908571,13.138572,12.844286,13.115714,11.354239,259043400\n2006-11-29,13.285714,13.307143,12.892858,13.114285,11.353003,289270800\n2006-11-30,13.172857,13.240000,13.008572,13.094286,11.335690,217621600\n2006-12-01,13.114285,13.190000,12.871428,13.045714,11.293642,198769900\n2006-12-04,13.125714,13.150000,12.928572,13.017143,11.268908,177384200\n2006-12-05,13.092857,13.190000,12.981428,13.038571,11.287459,165709600\n2006-12-06,12.948571,13.055715,12.810000,12.832857,11.109372,159546100\n2006-12-07,12.861428,12.928572,12.414286,12.434286,10.764329,251206900\n2006-12-08,12.461429,12.770000,12.428572,12.608571,10.915209,196069300\n2006-12-11,12.700000,12.757143,12.578571,12.678572,10.975807,124945100\n2006-12-12,12.658571,12.691428,12.218572,12.305715,10.653026,256655000\n2006-12-13,12.564285,12.724286,12.450000,12.721429,11.012909,214263000\n2006-12-14,12.721429,12.857142,12.608571,12.650000,10.951073,208082700\n2006-12-15,12.717143,12.745714,12.475715,12.531428,10.848425,184984800\n2006-12-18,12.518572,12.571428,12.084286,12.210000,10.570165,180394200\n2006- ...

# %%
# Store the data as a panda dataframe
AAPL = pd.read_csv('AAPL.csv')
# Set the date as the index
AAPL = AAPL.set_index(pd.DatetimeIndex(AAPL['Date'].values)) 

# Show the data
AAPL 

# Truncate the data until 26th Dec 2006
AAPL = AAPL[0:60] # 60 rows mark until 26th Dec 2006
max_close = AAPL['Close'].max()
min_close = AAPL['Close'].min()

print(AAPL)
print("Max Close Price = ", max_close)
print("Min Close Price = ", min_close)
# Out:
#                   Date       Open       High  ...      Close  Adj Close     Volume
# 2006-10-02  2006-10-02  10.728572  10.838572  ...  10.694285   9.258014  178159800
# 2006-10-03  2006-10-03  10.635715  10.707143  ...  10.582857   9.161551  197677200
# 2006-10-04  2006-10-04  10.585714  10.780000  ...  10.768572   9.322326  207270700
# 2006-10-05  2006-10-05  10.647142  10.880000  ...  10.690000   9.254304  170970800
# 2006-10-06  2006-10-06  10.631429  10.720000  ...  10.602858   9.178867  116739700
# 2006-10-09  2006-10-09  10.542857  10.725715  ...  10.661428   9.229569  109555600
# 2006-10-10  2006-10-10  10.648571  10.654285  ...  10.544286   9.128160  132897100
# 2006-10-11  2006-10-11  10.488571  10.568571  ...  10.461429   9.056430  142963800
# 2006-10-12  2006-10-12  10.515715  10.770000  ...  10.751429   9.307484  148213800
# 2006-10-13  2006-10-13  10.804286  10.982857  ...  10.717143   9.277802  171049200
# 2006-10-16  2006-10-16  10.741428  10.840000  ...  10.771428   9.324798  127173200
# 2006-12-08  2006-12-08  12.461429  12.770000  ...  12.608571  10.915209  196069300
# 2006-12-11  2006-12-11  12.700000  12.757143  ...  12.678572  10.975807  124945100
# 2006-12-12  2006-12-12  12.658571  12.691428  ...  12.305715  10.653026  256655000
# 2006-12-13  2006-12-13  12.564285  12.724286  ...  12.721429  11.012909  214263000
# 2006-12-14  2006-12-14  12.721429  12.857142  ...  12.650000  10.951073  208082700
# 2006-12-15  2006-12-15  12.717143  12.745714  ...  12.531428  10.848425  184984800
# 2006-12-18  2006-12-18  12.518572  12.571428  ...  12.210000  10.570165  180394200
# 2006-12-19  2006-12-19  12.104285  12.382857  ...  12.330000  10.674047  227851400
# 2006-12-20  2006-12-20  12.352858  12.381429  ...  12.108571  10.482360  141922900
# 2006-12-21  2006-12-21  12.100000  12.211429  ...  11.842857  10.252333  225899800
# 2006-12-22  2006-12-22  11.922857  12.005714  ...  11.742857  10.165761  153325900
# 2006-12-26  2006-12-26  11.735714  11.795714  ...  11.644286  10.080429  122672200
#
# [60 rows x 7 columns]
# Max Close Price =  13.115714
# Min Close Price =  10.461428999999999

# %%
# Plot the data

plt.figure(figsize=(20.5,12.5)) # sizes are in inches
plt.plot(AAPL['Close'], label = 'AAPL') # adjusted price on the x axis
plt.title('Apple Close Price History')
plt.xlabel('02 Oct 2006 - 26th Dec 2006')
plt.xticks(rotation=45)
plt.ylabel('Adj. Close Price USD ($)')
plt.legend(loc='upper left')
plt.show()

# %%
# Calculate the three moving averages

# Calculate the short term exponential moving average (SEMA)
shortPeriod = 5
Short_EMA = AAPL.Close.ewm(span=shortPeriod, adjust= False).mean()

# Calculate the medium exponential moving average (MEMA)
medPeriod = 21
Med_EMA = AAPL.Close.ewm(span=medPeriod, adjust= False).mean()

# Calculate the long term exponential moving average (SEMA)
longPeriod = 63 
Long_EMA = AAPL.Close.ewm(span=longPeriod, adjust= False).mean()

# %%
# Plot the 3 moving averages

plt.figure(figsize=(20.5,12.5)) # sizes are in inches
plt.plot(AAPL['Close'], label = 'AAPL Close') # Close Price

plt.plot(Short_EMA, label = 'SEMA') # Short Average
plt.plot(Med_EMA, label = 'MEMA') # Medium Average
plt.plot(Long_EMA, label = 'LEMA') # Long Average


plt.title('Apple Close Price History')
plt.xlabel('02 Oct 2006 - 26th Dec 2006')
plt.xticks(rotation=45)
plt.ylabel('Close Price USD ($)')
plt.legend(loc='upper left')
plt.show()

# %%
# Store EMAs in the dataset
AAPL['SEMA'] = Short_EMA
AAPL['MEMA'] = Med_EMA
AAPL['LEMA'] = Long_EMA
AAPL
# Out:
#                   Date       Open  ...  Buy_Signal_Price  Sell_Signal_Price
# 2006-10-02  2006-10-02  10.728572  ...               NaN                NaN
# 2006-10-03  2006-10-03  10.635715  ...               NaN                NaN
# 2006-10-04  2006-10-04  10.585714  ...               NaN                NaN
# 2006-10-05  2006-10-05  10.647142  ...               NaN                NaN
# 2006-10-06  2006-10-06  10.631429  ...               NaN                NaN
# 2006-10-09  2006-10-09  10.542857  ...               NaN                NaN
# 2006-10-10  2006-10-10  10.648571  ...               NaN                NaN
# 2006-10-11  2006-10-11  10.488571  ...               NaN                NaN
# 2006-10-12  2006-10-12  10.515715  ...               NaN                NaN
# 2006-12-22  2006-12-22  11.922857  ...               NaN                NaN
# 2006-12-26  2006-12-26  11.735714  ...               NaN                NaN
#
# [60 rows x 12 columns]

# %%
# Investment signal
def investment_signal(data):
  sigPriceToBuy = []
  sigPriceToSell = []
  flagLong = 0 # flag to check when STMA crosses over LTMA
  flagShort = 0 
  for i in range(len(data)):
    if data['MEMA'][i]< data['LEMA'][i] and data['SEMA'][i]< data['MEMA'][i] and flagLong == 0 and flagShort == 0:
        sigPriceToBuy.append(data['Close'][i]) # good time to buy
        sigPriceToSell.append(np.nan)
        flagShort = 1
    
    elif data['SEMA'][i]> data['MEMA'][i] and flagShort == 1:
        sigPriceToBuy.append(np.nan) 
        sigPriceToSell.append(data['Close'][i]) # good time to sell
        flagShort = 0
        
    elif data['MEMA'][i]> data['LEMA'][i] and data['SEMA'][i]> data['MEMA'][i] and flagLong == 0 and flagShort == 0:
        sigPriceToBuy.append(np.nan)
        sigPriceToSell.append(np.nan)
        flagLong =1
    
    elif data['SEMA'][i]< data['MEMA'][i] and flagLong == 1:
        sigPriceToBuy.append(np.nan) 
        sigPriceToSell.append(data['Close'][i]) # good time to sell
        flagLong = 0    

    else:
      sigPriceToBuy.append(np.nan)
      sigPriceToSell.append(np.nan)

  return (sigPriceToBuy,sigPriceToSell)

# %%
# Store the Buy and Sell data
buy_sell = investment_signal(AAPL)
AAPL['Buy_Signal_Price'] = buy_sell[0]
AAPL['Sell_Signal_Price'] = buy_sell[1]
AAPL
# Out:
#                   Date       Open  ...  Buy_Signal_Price  Sell_Signal_Price
# 2006-10-02  2006-10-02  10.728572  ...               NaN                NaN
# 2006-10-03  2006-10-03  10.635715  ...         10.582857                NaN
# 2006-10-04  2006-10-04  10.585714  ...               NaN          10.768572
# 2006-10-05  2006-10-05  10.647142  ...               NaN                NaN
# 2006-10-06  2006-10-06  10.631429  ...         10.602858                NaN
# 2006-10-09  2006-10-09  10.542857  ...               NaN                NaN
# 2006-10-10  2006-10-10  10.648571  ...               NaN                NaN
# 2006-10-11  2006-10-11  10.488571  ...               NaN                NaN
# 2006-10-12  2006-10-12  10.515715  ...               NaN                NaN
# 2006-10-13  2006-10-13  10.804286  ...               NaN                NaN
# 2006-10-16  2006-10-16  10.741428  ...               NaN          10.771428
# 2006-10-17  2006-10-17  10.720000  ...         10.612857                NaN
# 2006-10-18  2006-10-18  10.678572  ...               NaN                NaN
# 2006-10-19  2006-10-19  11.322857  ...               NaN          11.284286
# 2006-10-20  2006-10-20  11.281428  ...               NaN                NaN
# 2006-10-23  2006-10-23  11.427143  ...               NaN                NaN
# 2006-10-24  2006-10-24  11.601429  ...               NaN                NaN
# 2006-10-25  2006-10-25  11.621428  ...               NaN                NaN
# 2006-10-26  2006-10-26  11.700000  ...               NaN                NaN
# 2006-10-27  2006-10-27  11.678572  ...               NaN                NaN
# 2006-10-30  2006-10-30  11.427143  ...               NaN                NaN
# 2006-10-31  2006-10-31  11.635715  ...               NaN                NaN
# 2006-11-01  2006-11-01  11.585714  ...               NaN                NaN
# 2006-11-02  2006-11-02  11.274285  ...               NaN                NaN
# 2006-11-03  2006-11-03  11.337143  ...               NaN                NaN
# 2006-11-06  2006-11-06  11.278571  ...               NaN                NaN
# 2006-11-07  2006-11-07  11.492857  ...               NaN                NaN
# 2006-11-08  2006-11-08  11.431429  ...               NaN                NaN
# 2006-11-09  2006-11-09  11.842857  ...               NaN                NaN
# 2006-11-10  2006-11-10  11.935715  ...               NaN                NaN
# 2006-11-13  2006-11-13  11.888572  ...               NaN                NaN
# 2006-11-14  2006-11-14  12.114285  ...               NaN                NaN
# 2006-11-15  2006-11-15  12.150000  ...               NaN                NaN
# 2006-11-16  2006-11-16  12.124286  ...               NaN                NaN
# 2006-11-17  2006-11-17  12.162857  ...               NaN                NaN
# 2006-11-20  2006-11-20  12.200000  ...               NaN                NaN
# 2006-11-21  2006-11-21  12.488571  ...               NaN                NaN
# 2006-11-22  2006-11-22  12.712857  ...               NaN                NaN
# 2006-11-24  2006-11-24  12.790000  ...               NaN                NaN
# 2006-11-27  2006-11-27  13.215714  ...               NaN                NaN
# 2006-11-28  2006-11-28  12.908571  ...               NaN                NaN
# 2006-11-29  2006-11-29  13.285714  ...               NaN                NaN
# 2006-11-30  2006-11-30  13.172857  ...               NaN                NaN
# 2006-12-01  2006-12-01  13.114285  ...               NaN                NaN
# 2006-12-04  2006-12-04  13.125714  ...               NaN                NaN
# 2006-12-05  2006-12-05  13.092857  ...               NaN                NaN
# 2006-12-06  2006-12-06  12.948571  ...               NaN                NaN
# 2006-12-07  2006-12-07  12.861428  ...               NaN                NaN
# 2006-12-08  2006-12-08  12.461429  ...               NaN                NaN
# 2006-12-11  2006-12-11  12.700000  ...               NaN                NaN
# 2006-12-12  2006-12-12  12.658571  ...               NaN                NaN
# 2006-12-13  2006-12-13  12.564285  ...               NaN                NaN
# 2006-12-14  2006-12-14  12.721429  ...               NaN                NaN
# 2006-12-15  2006-12-15  12.717143  ...               NaN                NaN
# 2006-12-18  2006-12-18  12.518572  ...               NaN          12.210000
# 2006-12-19  2006-12-19  12.104285  ...               NaN                NaN
# 2006-12-20  2006-12-20  12.352858  ...               NaN                NaN
# 2006-12-21  2006-12-21  12.100000  ...               NaN                NaN
# 2006-12-22  2006-12-22  11.922857  ...               NaN                NaN
# 2006-12-26  2006-12-26  11.735714  ...               NaN                NaN
#
# [60 rows x 12 columns]

# %%
# Plot the data with buy and signal markers
plt.figure(figsize=(20.5,12.5)) # sizes are in inches

# Close Price
plt.plot(AAPL['Close'],label='Close Price', alpha = 0.35)

plt.plot(Short_EMA, label = 'SEMA', alpha = 0.35) # Short Average
plt.plot(Med_EMA, label = 'MEMA', alpha = 0.35) # Medium Average
plt.plot(Long_EMA, label = 'LEMA', alpha = 0.35) # Long Average

# Buy Signal
plt.scatter(AAPL.index, AAPL['Buy_Signal_Price'], label = 'Buy', marker = "^", color="green",s=100) # Decision Made to buy

# Sell Signal
plt.scatter(AAPL.index,AAPL['Sell_Signal_Price'], label = 'Sell',  marker = "v", color="red",s=100) # long term moving avg

plt.title('Apple Close Price History- Buy & Sell Signals')
plt.xlabel('02 Oct 2006 - 26th Dec 2006')
plt.xticks(rotation=45)
plt.xticks(rotation = 45)
plt.ylabel('Close Price USD ($)')
plt.legend(loc='upper left')
plt.show()

# %%
# TODO: Display net profit/loss
